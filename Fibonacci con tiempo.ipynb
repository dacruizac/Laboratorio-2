# %%
import time
import numpy as np
#import matplotlib.pyplot as plt
import pylab as plt
# %matplotlib inline
from __future__ import unicode_literals


def fibonacci_time(n):
    t=0
    start_time=time.clock();
    if (n==0):
        return (time.clock()-start_time);
    x=0;
    y=1;
    for i in range(0,n-1):
        y=y+x;
        x=y-x;
    t=time.clock()-start_time;
    return t

def fibonacci(n):
    if (n==0):
        return 0;
    x=0;
    y=1;
    for i in range(0,n-1):
        y=y+x;
        x=y-x;
    return y;

nf=range(0,60000,100)
times=[]
for x in range(len(nf)):
    times.append(fibonacci_time(nf[x]));

plt.xlabel('fibonacci')
plt.ylabel('tiempo')
plt.plot(nf, times);
